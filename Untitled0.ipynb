# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya20032004/Newamb/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
#%%
insurance=pd.read_csv("https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv")
insurance
#%%
# Converting  object into numerical features
insurance_one_hot = pd.get_dummies(insurance)
insurance_one_hot.head()
# returns first five rows of the dataframe|
#%%
# Create x,y and labels
x=insurance_one_hot.drop('charges',axis=1)
y=insurance_one_hot['charges']
#%%
x.head()
#%%
y.head()
#%%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size=0.2, random_state=42)
len(x), len(x_test),len(x_train)
x_train.head()
#%%
tf.random.set_seed(42)
#build a model
insurance_model = tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])
# Compiling a model
insurance_model.compile(loss=tf.keras.losses.mae,
                        optimizer=tf.keras.optimizers.SGD(),
                        metrics=['mae'])
# Fitting a model
insurance_model.fit(x_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 34/34 [==============================] - 1s 2ms/step - loss: 8725.6504 - mae: 8725.6504
# Epoch 2/100
# 34/34 [==============================] - 0s 1ms/step - loss: 7791.1953 - mae: 7791.1953
# Epoch 3/100
# 34/34 [==============================] - 0s 1ms/step - loss: 7544.1348 - mae: 7544.1348
# Epoch 4/100
# 34/34 [==============================] - 0s 2ms/step - loss: 7693.4565 - mae: 7693.4565
# Epoch 5/100
# 34/34 [==============================] - 0s 2ms/step - loss: 7668.3877 - mae: 7668.3877
# Epoch 6/100
# 34/34 [==============================] - 0s 1ms/step - loss: 7643.4023 - mae: 7643.4023
# Epoch 7/100
# 34/34 [==============================] - 0s 1ms/step - loss: 7521.2192 - mae: 7521.2192
# Epoch 8/100
# 34/34 [==============================] - 0s 1ms/step - loss: 7690.1890 - mae: 7690.1890
# Epoch 9/100
# 34/34 [==============================] - 0s 1ms/step - loss: 7450.0752 - mae: 7450.0752
# Epoch 10/100
# ...
