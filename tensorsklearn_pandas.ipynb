# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya20032004/Newamb/blob/main/tensorsklearn_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import pandas as pd
import matplotlib.pyplot as plt
#%%
insurance=pd.read_csv("https://raw.githubusercontent.com/stedy/Machine-Learning-with-R-datasets/master/insurance.csv")
insurance
#%%
# Converting  object into numerical features
insurance_one_hot = pd.get_dummies(insurance)
insurance_one_hot.head()
# returns first five rows of the dataframe|
#%%
# Create x,y and labels
x=insurance_one_hot.drop('charges',axis=1)
y=insurance_one_hot['charges']
#%%
x.head()
#%%
y.head()
#%%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size=0.2, random_state=42)
len(x), len(x_test),len(x_train)
x_train.head()
#%%
tf.random.set_seed(42)
#build a model
insurance_model = tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(1)
])
# Compiling a model
insurance_model.compile(loss=tf.keras.losses.mae,
                        optimizer=tf.keras.optimizers.SGD(),
                        metrics=['mae'])
# Fitting a model
insurance_model.fit(x_train, y_train, epochs=100)

# %%
insurance_model.evaluate(x_test, y_test)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 7302.6064 - mae: 7302.6064
# [7302.6064453125, 7302.6064453125]

# %%
# To try improve a model we will run experimnets

# %%
tf.random.set_seed(42)
insurance_model2= tf.keras.Sequential([
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(1)
])
insurance_model2.compile(
    loss=tf.keras.losses.mae,
    optimizer=tf.keras.optimizers.Adam(),
    metrics=["mae"]

)
insurance_model2.fit(x_train,y_train,epochs=500, verbose=1)
# Out:
# Epoch 1/500
# 34/34 [==============================] - 1s 3ms/step - loss: 13280.3320 - mae: 13280.3320
# Epoch 2/500
# 34/34 [==============================] - 0s 3ms/step - loss: 13101.9062 - mae: 13101.9062
# Epoch 3/500
# 34/34 [==============================] - 0s 2ms/step - loss: 12743.0244 - mae: 12743.0244
# Epoch 4/500
# 34/34 [==============================] - 0s 2ms/step - loss: 12042.0000 - mae: 12042.0000
# Epoch 5/500
# 34/34 [==============================] - 0s 2ms/step - loss: 10871.5625 - mae: 10871.5625
# Epoch 6/500
# 34/34 [==============================] - 0s 2ms/step - loss: 9392.3916 - mae: 9392.3916
# Epoch 7/500
# 34/34 [==============================] - 0s 2ms/step - loss: 8079.3867 - mae: 8079.3867
# Epoch 8/500
# 34/34 [==============================] - 0s 2ms/step - loss: 7501.1270 - mae: 7501.1270
# Epoch 9/500
# 34/34 [==============================] - 0s 2ms/step - loss: 7415.3892 - mae: 7415.3892
# Epoch 10/500
# ...

# %%
# Evaluate
insurance_model2.evaluate(x_test, y_test)
# Out:
# 9/9 [==============================] - 0s 2ms/step - loss: 3167.7266 - mae: 3167.7266
# [3167.7265625, 3167.7265625]
